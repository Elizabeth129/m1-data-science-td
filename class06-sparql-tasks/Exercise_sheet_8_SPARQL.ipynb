# %% [markdown]
# # Exercise Sheet #8
#
# ## Exercise 1
#
# For this exercise, you are require to write SPARQL queries and to check their answer on the following SPARQL endpoint: https://dbpedia.org/sparql.
#
# The following prefixes will be useful:
# - PREFIX dbo: <http://dbpedia.org/ontology/>
# - PREFIX dbr: <http://dbpedia.org/resource/>
# - PREFIX dbp: <http://dbpedia.org/property/>
#
# ### Question 1.1
#
# - Look up http://dbpedia.org/page/Alan_Bean. Write a query to retrieve the abstract.

# %% [markdown]
# <!-- write your code in between the backquotes -->
# ```
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT * WHERE
# {
#      dbr:Alan_Bean dbo:abstract ?x .
#      FILTER (langmatches(lang(?x), "EN"))
# }
# ```

# %% [markdown]
# ### Question 1.2
# - Modify the query to retrieve the abstract in a single language of your choice (e.g., only the french abstract).

# %% [markdown]
# <!-- write your code in between the backquotes -->
# ```
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT * WHERE
# {
#      dbr:Alan_Bean dbo:abstract ?x .
#      FILTER (langmatches(lang(?x), "EN"))
# }
# ```

# %% [markdown]
# ### Question 1.3
# - Look at how the astronaut profession is specified (in http://dbpedia.org/page/Alan_Bean) and write a query to retrieve all astronauts.

# %% [markdown]
# <!-- write your code in between the backquotes -->
# ```
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT * WHERE
# {
#      ?x dbo:occupation|dbp:occupation|dbp:type dbr:Astronaut .
# }
# ```

# %% [markdown]
# ### Question 1.4
# - Write a query that counts the nb of astronauts.

# %% [markdown]
# <!-- write your code in between the backquotes -->
# ```
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT COUNT(*) as ?count WHERE
# {
#      ?x dbo:occupation|dbp:occupation|dbp:type dbr:Astronaut .
# }
# ```

# %% [markdown]
# ### Question 1.5
# - Retrieve all astronauts and their nationality: Try with and without the OPTIONAL clause; for each query, get the number of astronauts.

# %% [markdown]
# <!-- write your code in between the backquotes -->
# ```
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT * WHERE
# {
#      ?page dbo:occupation|dbp:occupation|dbp:type dbr:Astronaut ;
#           dbp:nationality ?nationality.
#
# }
#
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT * WHERE
# {
#      ?page dbo:occupation|dbp:occupation|dbp:type dbr:Astronaut.
#   OPTIONAL {?page  dbp:nationality ?nationality. }
#
# }
#
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT COUNT(*) WHERE
# {
#      ?page dbo:occupation|dbp:occupation|dbp:type dbr:Astronaut ;
#           dbp:nationality ?nationality.
#
# }
#
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT COUNT(*) WHERE
# {
#      ?page dbo:occupation|dbp:occupation|dbp:type dbr:Astronaut.
#   OPTIONAL {?page  dbp:nationality ?nationality. }
#
# }
# ```

# %% [markdown]
# ### Question 1.6
# - Retrieve all astronauts ordered in reverse alphabetical order .

# %% [markdown]
# <!-- write your code in between the backquotes -->
# ```
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT ?name WHERE
# {
#      ?page dbo:occupation|dbp:occupation|dbp:type dbr:Astronaut;
#                 dbo:birthName ?name
#  FILTER (langmatches(lang(?name), "EN"))
# } ORDER BY DESC(?page)
# ```

# %% [markdown]
# ### Question 1.7
# - Retrieve all astronauts grouped by nationality.

# %% [markdown]
# <!-- write your code in between the backquotes -->
# ```
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
#
# SELECT ?nationality COUNT(?nationality) as ?total_Astronauts WHERE
# {
#      ?page dbo:occupation|dbp:occupation|dbp:type dbr:Astronaut;
#                 dbp:nationality|dbo:nationality ?nationality
#
# } GROUP BY ?nationalitys
# ```

# %% [markdown]
# ## Exercise 2
# Using [SPARQLWrapper](https://rdflib.github.io/sparqlwrapper/), write a python program which applies the 7 queries above and display the results.

# %%
# %pip install sparqlwrapper
# Out:
# Collecting sparqlwrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Collecting rdflib>=6.1.1
#   Downloading rdflib-6.2.0-py3-none-any.whl (500 kB)
#      ------------------------------------- 500.3/500.3 kB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\liza2\appdata\local\programs\python\python310\lib\site-packages (from rdflib>=6.1.1->sparqlwrapper) (57.4.0)
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ---------------------------------------- 41.7/41.7 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing in c:\users\liza2\appdata\roaming\python\python310\site-packages (from rdflib>=6.1.1->sparqlwrapper) (3.0.9)
# Requirement already satisfied: six in c:\users\liza2\appdata\roaming\python\python310\site-packages (from isodate->rdflib>=6.1.1->sparqlwrapper) (1.16.0)
# Installing collected packages: isodate, rdflib, sparqlwrapper
# Successfully installed isodate-0.6.1 rdflib-6.2.0 sparqlwrapper-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
sparql = SPARQLWrapper("http://dbpedia.org/sparql/")
sparql.setQuery("""
  PREFIX dbo: <http://dbpedia.org/ontology/>
  PREFIX dbr: <http://dbpedia.org/resource/>
  PREFIX dbp: <http://dbpedia.org/property/>

  SELECT ?page WHERE 
  {
     # ?page dbo:occupation|dbp:occupation|dbp:type dbr:Astronaut .
  }
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    print(result["page"]["value"])
# Out:
# http://dbpedia.org/resource/David_Scott
# http://dbpedia.org/resource/Vance_D._Brand
# http://dbpedia.org/resource/Wally_Schirra
# http://dbpedia.org/resource/Walter_Cunningham
# http://dbpedia.org/resource/Dick_Scobee
# http://dbpedia.org/resource/Alan_Bean
# http://dbpedia.org/resource/Alan_Shepard
# http://dbpedia.org/resource/Alexei_Leonov
# http://dbpedia.org/resource/Alfred_Worden
# http://dbpedia.org/resource/Fred_Haise
# http://dbpedia.org/resource/Gene_Cernan
# http://dbpedia.org/resource/Samantha_Cristoforetti
# http://dbpedia.org/resource/William_Anders
# http://dbpedia.org/resource/William_Pogue
# http://dbpedia.org/resource/William_Shepherd
# http://dbpedia.org/resource/Gerald_Carr_(astronaut)
# http://dbpedia.org/resource/Marcos_Pontes
# http://dbpedia.org/resource/Jack_R._Lousma
# http://dbpedia.org/resource/James_Irwin
# http://dbpedia.org/resource/Ken_Mattingly
# http://dbpedia.org/resource/Matthias_Maurer
# http://dbpedia.org/resource/Clifton_Williams
# http://dbpedia.org/resource/John_S._Bull
# http://dbpedia.org/resource/Joseph_A._Walker
# http://dbpedia.org/resource/Barbara_Morgan
# http://dbpedia.org/resource/Insa_Thiele-Eich
# http://dbpedia.org/resource/Mirosław_Hermaszewski
# http://dbpedia.org/resource/Senku_Ishigami
# http://dbpedia.org/resource/Charles_Bassett
# http://dbpedia.org/resource/Charles_Duke
# http://dbpedia.org/resource/Howard_Wolowitz
# http://dbpedia.org/resource/Donn_F._Eisele
# http://dbpedia.org/resource/Duane_Graveline
# http://dbpedia.org/resource/Gus_Grissom
# http://dbpedia.org/resource/Richard_F._Gordon_Jr.
# http://dbpedia.org/resource/Robert_F._Overmyer
# http://dbpedia.org/resource/Robert_L._Stewart
# http://dbpedia.org/resource/Roger_B._Chaffee
# http://dbpedia.org/resource/Jessica_Watkins
# http://dbpedia.org/resource/Joe_Engle
# http://dbpedia.org/resource/Peggy_Whitson
# http://dbpedia.org/resource/Pete_Conrad
# http://dbpedia.org/resource/Theodore_Freeman
# http://dbpedia.org/resource/Thomas_P._Stafford
# http://dbpedia.org/resource/Thomas_Pesquet
# http://dbpedia.org/resource/Ed_White_(astronaut)
# http://dbpedia.org/resource/Edgar_Mitchell
# http://dbpedia.org/resource/Edward_Givens
# http://dbpedia.org/resource/Elliot_See
# http://dbpedia.org/resource/Michael_J._McCulley
# http://dbpedia.org/resource/Michael_J._Smith
# http://dbpedia.org/resource/Major_Tom
# http://dbpedia.org/resource/Andreas_Mogensen
# http://dbpedia.org/resource/Andrew_J._Feustel
# http://dbpedia.org/resource/Andrew_M._Allen
# http://dbpedia.org/resource/Daniel_Brandenstein
# http://dbpedia.org/resource/Daniel_W._Bursch
# http://dbpedia.org/resource/David_C._Hilmers
# http://dbpedia.org/resource/David_Leestma
# http://dbpedia.org/resource/David_M._Walker_(astronaut)
# http://dbpedia.org/resource/Vance_D._Brand
# http://dbpedia.org/resource/Walter_Cunningham
# http://dbpedia.org/resource/Dick_Scobee
# http://dbpedia.org/resource/Alan_Bean
# http://dbpedia.org/resource/Albert_H._Crews
# http://dbpedia.org/resource/Francis_G._Neubeck
# http://dbpedia.org/resource/Frank_L._Culbertson_Jr.
# http://dbpedia.org/resource/Fred_Haise
# http://dbpedia.org/resource/Frederick_Hauck
# http://dbpedia.org/resource/Frederick_W._Sturckow
# http://dbpedia.org/resource/G._David_Low
# http://dbpedia.org/resource/Gary_Payton_(astronaut)
# http://dbpedia.org/resource/Gene_Cernan
# http://dbpedia.org/resource/George_Nelson_(astronaut)
# http://dbpedia.org/resource/Samantha_Cristoforetti
# http://dbpedia.org/resource/William_Anders
# http://dbpedia.org/resource/William_B._Lenoir
# http://dbpedia.org/resource/William_C._McCool
# http://dbpedia.org/resource/William_E._Thornton
# http://dbpedia.org/resource/William_H._Dana
# http://dbpedia.org/resource/William_Oefelein
# http://dbpedia.org/resource/William_Pogue
# http://dbpedia.org/resource/William_S._McArthur
# http://dbpedia.org/resource/William_Shepherd
# http://dbpedia.org/resource/Anthony_W._England
# http://dbpedia.org/resource/Eric_Boe
# http://dbpedia.org/resource/Gerald_Carr_(astronaut)
# http://dbpedia.org/resource/Mark_C._Lee
# http://dbpedia.org/resource/Mark_N._Brown
# http://dbpedia.org/resource/Terence_T._Henricks
# http://dbpedia.org/resource/Terrence_W._Wilcutt
# http://dbpedia.org/resource/Terry_Hart
# http://dbpedia.org/resource/Brewster_H._Shaw
# http://dbpedia.org/resource/Brian_Duffy_(astronaut)
# http://dbpedia.org/resource/Brian_O'Leary
# http://dbpedia.org/resource/Bruce_E._Melnick
# http://dbpedia.org/resource/Bruce_McCandless_II
# http://dbpedia.org/resource/Bryan_D._O'Connor
# http://dbpedia.org/resource/Jack_R._Lousma
# http://dbpedia.org/resource/James_Buchli
# http://dbpedia.org/resource/James_C._Adamson
# http://dbpedia.org/resource/James_H._Newman
# http://dbpedia.org/resource/James_Irwin
# http://dbpedia.org/resource/James_M._Taylor
# http://dbpedia.org/resource/James_S._Voss
# http://dbpedia.org/resource/James_W._Wood
# http://dbpedia.org/resource/James_van_Hoften
# http://dbpedia.org/resource/Jan_Davis
# http://dbpedia.org/resource/Kathleen_Rubins
# http://dbpedia.org/resource/Kathryn_C._Thornton
# http://dbpedia.org/resource/Ken_Bowersox
# http://dbpedia.org/resource/Ken_Mattingly
# http://dbpedia.org/resource/Kenneth_D._Cameron
# http://dbpedia.org/resource/Kenneth_S._Reightler_Jr.
# http://dbpedia.org/resource/Kent_Rominger
# http://dbpedia.org/resource/Kevin_A._Ford
# http://dbpedia.org/resource/Kevin_P._Chilton
# http://dbpedia.org/resource/Kevin_R._Kregel
# http://dbpedia.org/resource/Matthias_Maurer
# http://dbpedia.org/resource/Randolph_Bresnik
# http://dbpedia.org/resource/Norman_Thagard
# http://dbpedia.org/resource/Clifton_Williams
# http://dbpedia.org/resource/John_M._Fabian
# http://dbpedia.org/resource/John_Oliver_Creighton
# http://dbpedia.org/resource/John_S._Bull
# http://dbpedia.org/resource/Jon_McBride
# http://dbpedia.org/resource/Joseph_A._Walker
# http://dbpedia.org/resource/Joseph_M._Acaba
# http://dbpedia.org/resource/Joseph_P._Allen
# http://dbpedia.org/resource/Joseph_R._Tanner
# http://dbpedia.org/resource/Jack_D._Fischer
# http://dbpedia.org/resource/C._Gordon_Fullerton
# http://dbpedia.org/resource/Charles_Bassett
# http://dbpedia.org/resource/Charles_D._Gemar
# http://dbpedia.org/resource/Charles_Duke
# http://dbpedia.org/resource/Charles_L._Veach
# http://dbpedia.org/resource/Chen_Dong_(taikonaut)
# http://dbpedia.org/resource/Christer_Fuglesang
# http://dbpedia.org/resource/Christopher_Cassidy
# http://dbpedia.org/resource/Steven_Hawley
# http://dbpedia.org/resource/Steven_Lindsey
# http://dbpedia.org/resource/Steven_R._Nagel
# http://dbpedia.org/resource/Story_Musgrave
# http://dbpedia.org/resource/Stuart_Roosa
# http://dbpedia.org/resource/Carl_J._Meade
# http://dbpedia.org/resource/Lachlan_Macleay
# http://dbpedia.org/resource/Don_L._Lind
# http://dbpedia.org/resource/Donald_E._Williams
# http://dbpedia.org/resource/Donald_H._Peterson
# http://dbpedia.org/resource/Donald_Holmquest
# http://dbpedia.org/resource/Donald_R._McMonagle
# http://dbpedia.org/resource/Donn_F._Eisele
# http://dbpedia.org/resource/Curtis_Brown
# http://dbpedia.org/resource/Dale_Gardner
# http://dbpedia.org/resource/Gregory_C._Johnson
# http://dbpedia.org/resource/Guion_Bluford
# http://dbpedia.org/resource/Guy_Gardner_(astronaut)
# http://dbpedia.org/resource/Henry_Charles_Gordon
# http://dbpedia.org/resource/Henry_Hartsfield
# http://dbpedia.org/resource/Richard_A._Searfoss
# http://dbpedia.org/resource/Richard_E._Lawyer
# http://dbpedia.org/resource/Richard_F._Gordon_Jr.
# http://dbpedia.org/resource/Richard_M._Linnehan
# http://dbpedia.org/resource/Richard_N._Richards
# http://dbpedia.org/resource/Richard_O._Covey
# http://dbpedia.org/resource/Rick_Husband
# http://dbpedia.org/resource/Robert_A._Parker
# http://dbpedia.org/resource/Robert_A._Rushworth
# http://dbpedia.org/resource/Robert_C._Springer
# http://dbpedia.org/resource/Robert_Crippen
# http://dbpedia.org/resource/Robert_Curbeam
# http://dbpedia.org/resource/Robert_F._Overmyer
# http://dbpedia.org/resource/Robert_Henry_Lawrence_Jr.
# http://dbpedia.org/resource/Robert_L._Gibson
# http://dbpedia.org/resource/Robert_L._Stewart
# http://dbpedia.org/resource/Robert_Michael_White
# http://dbpedia.org/resource/Roger_B._Chaffee
# http://dbpedia.org/resource/Jeffrey_Ashby
# http://dbpedia.org/resource/Jessica_Watkins
# http://dbpedia.org/resource/Jim_Wetherbee
# http://dbpedia.org/resource/Jing_Haipeng
# http://dbpedia.org/resource/Joe_Engle
# http://dbpedia.org/resource/Joe_F._Edwards_Jr.
# http://dbpedia.org/resource/John_B._McKay
# http://dbpedia.org/resource/John_Casper
# http://dbpedia.org/resource/John_E._Blaha
# http://dbpedia.org/resource/Pierre_J._Thuot
# http://dbpedia.org/resource/Piers_Sellers
# http://dbpedia.org/resource/Theodore_Freeman
# http://dbpedia.org/resource/Thomas_Akers
# http://dbpedia.org/resource/Thomas_Pesquet
# http://dbpedia.org/resource/Thomas_Reiter
# http://dbpedia.org/resource/Timothy_Kopra
# http://dbpedia.org/resource/Winston_E._Scott
# http://dbpedia.org/resource/Edgar_Mitchell
# http://dbpedia.org/resource/Edward_Givens
# http://dbpedia.org/resource/Eileen_Collins
# http://dbpedia.org/resource/Karl_Gordon_Henize
# http://dbpedia.org/resource/Karol_J._Bobko
# http://dbpedia.org/resource/Loren_Shriver
# http://dbpedia.org/resource/Sherwood_C._Spring
# http://dbpedia.org/resource/Stephen_Robinson
# http://dbpedia.org/resource/Stephen_S._Oswald
# http://dbpedia.org/resource/Bjarni_Tryggvason
# http://dbpedia.org/resource/Michael_A._Baker
# http://dbpedia.org/resource/Michael_Coats
# http://dbpedia.org/resource/Michael_Collins_(astronaut)
# http://dbpedia.org/resource/Michael_Fincke
# http://dbpedia.org/resource/Michael_Foreman_(astronaut)
# http://dbpedia.org/resource/Michael_J._Adams
# http://dbpedia.org/resource/Michael_J._McCulley
# http://dbpedia.org/resource/Michael_J._Smith
# http://dbpedia.org/resource/Michael_López-Alegría
# http://dbpedia.org/resource/Michael_P._Anderson
# http://dbpedia.org/resource/Michael_R._Clifford
# http://dbpedia.org/resource/Mike_Massimino
# http://dbpedia.org/resource/Mike_Mullane
# http://dbpedia.org/resource/Paul_J._Weitz
# http://dbpedia.org/resource/Paul_Lockhart
# http://dbpedia.org/resource/Ronald_J._Garan_Jr.
# http://dbpedia.org/resource/Ronald_J._Grabe
# http://dbpedia.org/resource/Russell_L._Rogers
# http://dbpedia.org/resource/Rusty_Schweickart
# http://dbpedia.org/resource/S._David_Griggs
# http://dbpedia.org/resource/David_Scott
# http://dbpedia.org/resource/Valentina_Tereshkova
# http://dbpedia.org/resource/Vance_D._Brand
# http://dbpedia.org/resource/Vladimir_Kovalyonok
# http://dbpedia.org/resource/Vladimír_Remek
# http://dbpedia.org/resource/Wally_Schirra
# http://dbpedia.org/resource/Walter_Cunningham
# http://dbpedia.org/resource/Dick_Scobee
# http://dbpedia.org/resource/Alan_Bean
# http://dbpedia.org/resource/Alan_Shepard
# http://dbpedia.org/resource/Aleksei_Gubarev
# http://dbpedia.org/resource/Aleksey_Ovchinin
# http://dbpedia.org/resource/Alexei_Leonov
# http://dbpedia.org/resource/Alfred_Worden
# http://dbpedia.org/resource/Artemis_Fowl_II
# http://dbpedia.org/resource/Frank_Borman
# http://dbpedia.org/resource/Fyodor_Yurchikhin
# http://dbpedia.org/resource/Gene_Cernan
# http://dbpedia.org/resource/Samantha_Cristoforetti
# http://dbpedia.org/resource/William_Anders
# http://dbpedia.org/resource/William_Pogue
# http://dbpedia.org/resource/William_Shepherd
# http://dbpedia.org/resource/Gerald_Carr_(astronaut)
# http://dbpedia.org/resource/Marcos_Pontes
# http://dbpedia.org/resource/Mario_Runco_Jr.
# http://dbpedia.org/resource/Mark_P._Stucky
# http://dbpedia.org/resource/Mary_Helen_Johnston
# http://dbpedia.org/resource/Boris_Morukov
# http://dbpedia.org/resource/Jack_R._Lousma
# http://dbpedia.org/resource/James_Irwin
# http://dbpedia.org/resource/Ken_Mattingly
# http://dbpedia.org/resource/Matthias_Maurer
# http://dbpedia.org/resource/Rakesh_Sharma
# http://dbpedia.org/resource/Clifton_Williams
# http://dbpedia.org/resource/John_S._Bull
# http://dbpedia.org/resource/Joseph_A._Walker
# http://dbpedia.org/resource/Scott_Carpenter
# http://dbpedia.org/resource/Molly_Woods
# http://dbpedia.org/resource/Barbara_Morgan
# http://dbpedia.org/resource/Barry_E._Wilmore
# http://dbpedia.org/resource/Insa_Thiele-Eich
# http://dbpedia.org/resource/Mirosław_Hermaszewski
# http://dbpedia.org/resource/Nadezhda_Kuzhelnaya
# http://dbpedia.org/resource/Senku_Ishigami
# http://dbpedia.org/resource/Buzz_Aldrin
# http://dbpedia.org/resource/Charles_Bassett
# http://dbpedia.org/resource/Charles_Duke
# http://dbpedia.org/resource/Chen_Dong_(taikonaut)
# http://dbpedia.org/resource/Chen_Quan
# http://dbpedia.org/resource/Howard_Wolowitz
# http://dbpedia.org/resource/Donn_F._Eisele
# http://dbpedia.org/resource/Duane_Graveline
# http://dbpedia.org/resource/Sonny_Carter
# http://dbpedia.org/resource/Gus_Grissom
# http://dbpedia.org/resource/Hervé_Stevenin
# http://dbpedia.org/resource/Richard_F._Gordon_Jr.
# http://dbpedia.org/resource/Robert_F._Overmyer
# http://dbpedia.org/resource/Robert_L._Stewart
# http://dbpedia.org/resource/Roberta_Bondar
# http://dbpedia.org/resource/Roger_B._Chaffee
# http://dbpedia.org/resource/Jessica_Meir
# http://dbpedia.org/resource/Joe_Engle
# http://dbpedia.org/resource/Peggy_Whitson
# http://dbpedia.org/resource/Pete_Conrad
# http://dbpedia.org/resource/Pyotr_Klimuk
# http://dbpedia.org/resource/Theodore_Freeman
# http://dbpedia.org/resource/Thomas_P._Stafford
# http://dbpedia.org/resource/Thomas_Pesquet
# http://dbpedia.org/resource/Tim_Peake
# http://dbpedia.org/resource/Ed_White_(astronaut)
# http://dbpedia.org/resource/Edgar_Mitchell
# http://dbpedia.org/resource/Edward_Givens
# http://dbpedia.org/resource/Elliot_See
# http://dbpedia.org/resource/Oleg_Skripochka
# http://dbpedia.org/resource/Sheikh_Muszaphar_Shukor
# http://dbpedia.org/resource/Igor_Volk
# http://dbpedia.org/resource/List_of_Planet_of_the_Apes_characters
# http://dbpedia.org/resource/Michael_Collins_(astronaut)
# http://dbpedia.org/resource/Michael_J._McCulley
# http://dbpedia.org/resource/Michael_J._Smith
# http://dbpedia.org/resource/Ed_Straker
# http://dbpedia.org/resource/Yuri_Gagarin
# http://dbpedia.org/resource/Major_Tom
# http://dbpedia.org/resource/Jessica_Watkins__Jessica_Watkins__1
# http://dbpedia.org/resource/Fred_Haise__Fred_W._Haise_Jr.__1
