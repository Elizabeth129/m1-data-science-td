# %% [markdown]
# # Exercise Sheet \# 7 - Interfacing Python with SQL databases

# %% [markdown]
# In this exercises, you are asked to design python code which can interact with a SQLite database. We will use again the [SQL database](http://www.sqlitetutorial.net/wp-content/uploads/2018/03/chinook.zip) from Exercise Sheet \#6.

# %% [markdown]
# ## Exercise 1
#
# Write a python script, which covers questions 1.5 to 1.9 from Exercise Sheet \#5, using the SQLalchemy API.

# %%
# %pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading SQLAlchemy-2.0.5.post1-cp310-cp310-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\liza2\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy) (4.4.0)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-2.0.2-cp310-cp310-win_amd64.whl (192 kB)
#      -------------------------------------- 192.2/192.2 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: greenlet, sqlalchemy
# Successfully installed greenlet-2.0.2 sqlalchemy-2.0.5.post1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import Column, ForeignKey, Integer, String, Numeric
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

Base = declarative_base() 

class Artists(Base):
  __tablename__ = 'artists'
  # Each column is also a python instance attribute
  artistid = Column(Integer, primary_key=True)
  name     = Column(String(120), nullable=False)

class Albums(Base):
  __tablename__ = 'albums'
  albumid  = Column(Integer, primary_key=True)
  title    = Column(String(160), nullable=False)
  artistid = Column(Integer, ForeignKey('artists.artistid'))
  artists  = relationship(Artists)
    
class Genres(Base):
  __tablename__ = 'genres'
  genreid  = Column(Integer, primary_key=True)
  name     = Column(String(120))

class Tracks(Base):
  __tablename__ = 'tracks'
  trackid     = Column(Integer, primary_key=True)
  albumid     = Column(Integer, ForeignKey('albums.albumid'))
  genreid     = Column(Integer, ForeignKey('genres.genreid'))    
  name        = Column(String(200))
  mediatypeid = Column(Integer)
  composer    = Column(String(220))
  milliseconds= Column(Integer)      
  bytes       = Column(Integer)
  unitprice   = Column(Numeric)
  albums = relationship(Albums)
  genres = relationship(Genres)

# Create an engine that stores data locally 
# (and create the corresponding db file if it does not exists)
engine = create_engine('sqlite:///chinook.db')

# Bind the engine to the metadata of the Base 
Base.metadata.bind = engine
DBSession = sessionmaker(bind=engine, autoflush=False) #autoflush set to false to avoid errors when inserting
session   = DBSession()


from sqlalchemy import func #to import functions used within queries
# Note the functions doc is available at https://docs.sqlalchemy.org/en/latest/orm/tutorial.html#common-filter-operators

#1.5: SELECT albumId, count(Trackid) FROM tracks group by albumId;
print('\n############ Number of tracks per album ###########\n')
q1_5 = session.query(Tracks.albumid, func.count(Tracks.trackid)).group_by(Tracks.albumid)
# print result
for _aid, _count in q1_5.all():
    print('Album Id: {}, Nb tracks: {}'.format(_aid, _count))

#1.6: SELECT AVG(milliseconds) from tracks;
print('\n############ Average track duration ###########\n')
q1_6 = session.query(func.avg(Tracks.milliseconds))
for _length in q1_6.first():
    print('Average track duration (in milliseconds): ' + str(_length))
    
#1.7: INSERT INTO artists SELECT MAX(artistid) +1, 'Bono' FROM artists;
print('\n############ Adding new artist ###########\n')
q1_7 = Artists(artistid= int(session.query(func.max(Artists.artistid)).first()[0]) + 1, name='Bono')
session.add(q1_7)
#session.commit() #when uncommented will add Bono every time the code is executed!

#1.8: SELECT * FROM artists WHERE artistid NOT IN (SELECT DISTINCT artistid FROM albums);
print('\n############ Artists who have no registered album ###########\n')
q1_8 = session.query(Artists).filter(~Artists.artistid.in_([x[0] for x in session.query(Albums.artistid).all()]))
# Note that .all() returns tuples even if we only query artist ids!
for _artist in q1_8.all():
    print(_artist.artistid, _artist.name)

#1.9: DELETE FROM artists WHERE name LIKE 'N%';
print('\n############ Artists whose name starts with N ###########\n')
q1_9 = session.query(Artists).filter(Artists.name.like('N%'))
for _artists in q1_9.all():
    print(_artists.artistid, _artists.name)
# Out:
# ############ Number of tracks per album ###########
#
# Album Id: 1, Nb tracks: 10
# Album Id: 2, Nb tracks: 1
# Album Id: 3, Nb tracks: 3
# Album Id: 4, Nb tracks: 8
# Album Id: 5, Nb tracks: 15
# Album Id: 6, Nb tracks: 13
# Album Id: 7, Nb tracks: 12
# Album Id: 8, Nb tracks: 14
# Album Id: 9, Nb tracks: 8
# Album Id: 10, Nb tracks: 14
# Album Id: 11, Nb tracks: 12
# Album Id: 12, Nb tracks: 12
# Album Id: 13, Nb tracks: 8
# Album Id: 14, Nb tracks: 13
# Album Id: 15, Nb tracks: 5
# Album Id: 16, Nb tracks: 7
# Album Id: 17, Nb tracks: 10
# Album Id: 18, Nb tracks: 17
# Album Id: 19, Nb tracks: 11
# Album Id: 20, Nb tracks: 11
# Album Id: 21, Nb tracks: 18
# Album Id: 22, Nb tracks: 3
# Album Id: 23, Nb tracks: 34
# Album Id: 24, Nb tracks: 23
# Album Id: 25, Nb tracks: 13
# Album Id: 26, Nb tracks: 17
# Album Id: 27, Nb tracks: 14
# Album Id: 28, Nb tracks: 10
# Album Id: 29, Nb tracks: 14
# Album Id: 30, Nb tracks: 14
# Album Id: 31, Nb tracks: 9
# Album Id: 32, Nb tracks: 14
# Album Id: 33, Nb tracks: 17
# Album Id: 34, Nb tracks: 17
# Album Id: 35, Nb tracks: 11
# Album Id: 36, Nb tracks: 17
# Album Id: 37, Nb tracks: 20
# Album Id: 38, Nb tracks: 12
# Album Id: 39, Nb tracks: 21
# Album Id: 40, Nb tracks: 12
# Album Id: 41, Nb tracks: 14
# Album Id: 42, Nb tracks: 14
# Album Id: 43, Nb tracks: 7
# Album Id: 44, Nb tracks: 6
# Album Id: 45, Nb tracks: 14
# Album Id: 46, Nb tracks: 13
# Album Id: 47, Nb tracks: 14
# Album Id: 48, Nb tracks: 13
# Album Id: 49, Nb tracks: 10
# Album Id: 50, Nb tracks: 4
# Album Id: 51, Nb tracks: 22
# Album Id: 52, Nb tracks: 15
# Album Id: 53, Nb tracks: 14
# Album Id: 54, Nb tracks: 20
# Album Id: 55, Nb tracks: 20
# Album Id: 56, Nb tracks: 15
# Album Id: 57, Nb tracks: 15
# Album Id: 58, Nb tracks: 9
# Album Id: 59, Nb tracks: 7
# Album Id: 60, Nb tracks: 7
# Album Id: 61, Nb tracks: 11
# Album Id: 62, Nb tracks: 7
# Album Id: 63, Nb tracks: 12
# Album Id: 64, Nb tracks: 9
# Album Id: 65, Nb tracks: 9
# Album Id: 66, Nb tracks: 10
# Album Id: 67, Nb tracks: 16
# Album Id: 68, Nb tracks: 9
# Album Id: 69, Nb tracks: 13
# Album Id: 70, Nb tracks: 13
# Album Id: 71, Nb tracks: 14
# Album Id: 72, Nb tracks: 18
# Album Id: 73, Nb tracks: 30
# Album Id: 74, Nb tracks: 12
# Album Id: 75, Nb tracks: 14
# Album Id: 76, Nb tracks: 15
# Album Id: 77, Nb tracks: 11
# Album Id: 78, Nb tracks: 14
# Album Id: 79, Nb tracks: 10
# Album Id: 80, Nb tracks: 10
# Album Id: 81, Nb tracks: 11
# Album Id: 82, Nb tracks: 13
# Album Id: 83, Nb tracks: 24
# Album Id: 84, Nb tracks: 16
# Album Id: 85, Nb tracks: 14
# Album Id: 86, Nb tracks: 15
# Album Id: 87, Nb tracks: 3
# Album Id: 88, Nb tracks: 12
# Album Id: 89, Nb tracks: 13
# Album Id: 90, Nb tracks: 12
# Album Id: 91, Nb tracks: 16
# Album Id: 92, Nb tracks: 14
# Album Id: 93, Nb tracks: 13
# Album Id: 94, Nb tracks: 11
# Album Id: 95, Nb tracks: 12
# Album Id: 96, Nb tracks: 11
# Album Id: 97, Nb tracks: 10
# Album Id: 98, Nb tracks: 11
# Album Id: 99, Nb tracks: 12
# Album Id: 100, Nb tracks: 9
# Album Id: 101, Nb tracks: 10
# Album Id: 102, Nb tracks: 18
# Album Id: 103, Nb tracks: 10
# Album Id: 104, Nb tracks: 10
# Album Id: 105, Nb tracks: 10
# Album Id: 106, Nb tracks: 9
# Album Id: 107, Nb tracks: 8
# Album Id: 108, Nb tracks: 10
# Album Id: 109, Nb tracks: 9
# Album Id: 110, Nb tracks: 8
# Album Id: 111, Nb tracks: 8
# Album Id: 112, Nb tracks: 8
# Album Id: 113, Nb tracks: 11
# Album Id: 114, Nb tracks: 8
# Album Id: 115, Nb tracks: 20
# Album Id: 116, Nb tracks: 10
# Album Id: 117, Nb tracks: 11
# Album Id: 118, Nb tracks: 11
# Album Id: 119, Nb tracks: 13
# Album Id: 120, Nb tracks: 17
# Album Id: 121, Nb tracks: 10
# Album Id: 122, Nb tracks: 14
# Album Id: 123, Nb tracks: 12
# Album Id: 124, Nb tracks: 14
# Album Id: 125, Nb tracks: 16
# Album Id: 126, Nb tracks: 15
# Album Id: 127, Nb tracks: 10
# Album Id: 128, Nb tracks: 8
# Album Id: 129, Nb tracks: 8
# Album Id: 130, Nb tracks: 7
# Album Id: 131, Nb tracks: 8
# Album Id: 132, Nb tracks: 9
# Album Id: 133, Nb tracks: 9
# Album Id: 134, Nb tracks: 10
# Album Id: 135, Nb tracks: 9
# Album Id: 136, Nb tracks: 7
# Album Id: 137, Nb tracks: 5
# Album Id: 138, Nb tracks: 4
# Album Id: 139, Nb tracks: 15
# Album Id: 140, Nb tracks: 16
# Album Id: 141, Nb tracks: 57
# Album Id: 142, Nb tracks: 14
# Album Id: 143, Nb tracks: 14
# Album Id: 144, Nb tracks: 10
# Album Id: 145, Nb tracks: 18
# Album Id: 146, Nb tracks: 18
# Album Id: 147, Nb tracks: 10
# Album Id: 148, Nb tracks: 12
# Album Id: 149, Nb tracks: 16
# Album Id: 150, Nb tracks: 10
# Album Id: 151, Nb tracks: 14
# Album Id: 152, Nb tracks: 8
# Album Id: 153, Nb tracks: 13
# Album Id: 154, Nb tracks: 8
# Album Id: 155, Nb tracks: 11
# Album Id: 156, Nb tracks: 9
# Album Id: 157, Nb tracks: 14
# Album Id: 158, Nb tracks: 13
# Album Id: 159, Nb tracks: 13
# Album Id: 160, Nb tracks: 15
# Album Id: 161, Nb tracks: 12
# Album Id: 162, Nb tracks: 17
# Album Id: 163, Nb tracks: 17
# Album Id: 164, Nb tracks: 12
# Album Id: 165, Nb tracks: 15
# Album Id: 166, Nb tracks: 14
# Album Id: 167, Nb tracks: 21
# Album Id: 168, Nb tracks: 12
# Album Id: 169, Nb tracks: 16
# Album Id: 170, Nb tracks: 1
# Album Id: 171, Nb tracks: 2
# Album Id: 172, Nb tracks: 1
# Album Id: 173, Nb tracks: 2
# Album Id: 174, Nb tracks: 14
# Album Id: 175, Nb tracks: 12
# Album Id: 176, Nb tracks: 14
# Album Id: 177, Nb tracks: 10
# Album Id: 178, Nb tracks: 16
# Album Id: 179, Nb tracks: 13
# Album Id: 180, Nb tracks: 15
# Album Id: 181, Nb tracks: 11
# Album Id: 182, Nb tracks: 12
# Album Id: 183, Nb tracks: 9
# Album Id: 184, Nb tracks: 16
# Album Id: 185, Nb tracks: 17
# Album Id: 186, Nb tracks: 11
# Album Id: 187, Nb tracks: 11
# Album Id: 188, Nb tracks: 11
# Album Id: 189, Nb tracks: 14
# Album Id: 190, Nb tracks: 16
# Album Id: 191, Nb tracks: 10
# Album Id: 192, Nb tracks: 14
# Album Id: 193, Nb tracks: 17
# Album Id: 194, Nb tracks: 16
# Album Id: 195, Nb tracks: 15
# Album Id: 196, Nb tracks: 14
# Album Id: 197, Nb tracks: 8
# Album Id: 198, Nb tracks: 6
# Album Id: 199, Nb tracks: 12
# Album Id: 200, Nb tracks: 11
# Album Id: 201, Nb tracks: 16
# Album Id: 202, Nb tracks: 18
# Album Id: 203, Nb tracks: 17
# Album Id: 204, Nb tracks: 9
# Album Id: 205, Nb tracks: 10
# Album Id: 206, Nb tracks: 12
# Album Id: 207, Nb tracks: 11
# Album Id: 208, Nb tracks: 7
# Album Id: 209, Nb tracks: 10
# Album Id: 210, Nb tracks: 9
# Album Id: 211, Nb tracks: 18
# Album Id: 212, Nb tracks: 12
# Album Id: 213, Nb tracks: 18
# Album Id: 214, Nb tracks: 11
# Album Id: 215, Nb tracks: 14
# Album Id: 216, Nb tracks: 12
# Album Id: 217, Nb tracks: 14
# Album Id: 218, Nb tracks: 15
# Album Id: 219, Nb tracks: 15
# Album Id: 220, Nb tracks: 11
# Album Id: 221, Nb tracks: 20
# Album Id: 222, Nb tracks: 15
# Album Id: 223, Nb tracks: 15
# Album Id: 224, Nb tracks: 22
# Album Id: 225, Nb tracks: 16
# Album Id: 226, Nb tracks: 1
# Album Id: 227, Nb tracks: 19
# Album Id: 228, Nb tracks: 23
# Album Id: 229, Nb tracks: 26
# Album Id: 230, Nb tracks: 25
# Album Id: 231, Nb tracks: 24
# Album Id: 232, Nb tracks: 12
# Album Id: 233, Nb tracks: 11
# Album Id: 234, Nb tracks: 15
# Album Id: 235, Nb tracks: 11
# Album Id: 236, Nb tracks: 12
# Album Id: 237, Nb tracks: 17
# Album Id: 238, Nb tracks: 14
# Album Id: 239, Nb tracks: 10
# Album Id: 240, Nb tracks: 10
# Album Id: 241, Nb tracks: 14
# Album Id: 242, Nb tracks: 12
# Album Id: 243, Nb tracks: 17
# Album Id: 244, Nb tracks: 11
# Album Id: 245, Nb tracks: 12
# Album Id: 246, Nb tracks: 13
# Album Id: 247, Nb tracks: 15
# Album Id: 248, Nb tracks: 19
# Album Id: 249, Nb tracks: 6
# Album Id: 250, Nb tracks: 22
# Album Id: 251, Nb tracks: 25
# Album Id: 252, Nb tracks: 1
# Album Id: 253, Nb tracks: 24
# Album Id: 254, Nb tracks: 1
# Album Id: 255, Nb tracks: 23
# Album Id: 256, Nb tracks: 12
# Album Id: 257, Nb tracks: 12
# Album Id: 258, Nb tracks: 19
# Album Id: 259, Nb tracks: 17
# Album Id: 260, Nb tracks: 1
# Album Id: 261, Nb tracks: 17
# Album Id: 262, Nb tracks: 2
# Album Id: 263, Nb tracks: 2
# Album Id: 264, Nb tracks: 2
# Album Id: 265, Nb tracks: 2
# Album Id: 266, Nb tracks: 1
# Album Id: 267, Nb tracks: 1
# Album Id: 268, Nb tracks: 1
# Album Id: 269, Nb tracks: 10
# Album Id: 270, Nb tracks: 14
# Album Id: 271, Nb tracks: 14
# Album Id: 272, Nb tracks: 1
# Album Id: 273, Nb tracks: 1
# Album Id: 274, Nb tracks: 1
# Album Id: 275, Nb tracks: 1
# Album Id: 276, Nb tracks: 1
# Album Id: 277, Nb tracks: 1
# Album Id: 278, Nb tracks: 1
# Album Id: 279, Nb tracks: 1
# Album Id: 280, Nb tracks: 2
# Album Id: 281, Nb tracks: 1
# Album Id: 282, Nb tracks: 1
# Album Id: 283, Nb tracks: 1
# Album Id: 284, Nb tracks: 1
# Album Id: 285, Nb tracks: 1
# Album Id: 286, Nb tracks: 1
# Album Id: 287, Nb tracks: 1
# Album Id: 288, Nb tracks: 1
# Album Id: 289, Nb tracks: 1
# Album Id: 290, Nb tracks: 1
# Album Id: 291, Nb tracks: 1
# Album Id: 292, Nb tracks: 1
# Album Id: 293, Nb tracks: 1
# Album Id: 294, Nb tracks: 1
# Album Id: 295, Nb tracks: 1
# Album Id: 296, Nb tracks: 1
# Album Id: 297, Nb tracks: 1
# Album Id: 298, Nb tracks: 1
# Album Id: 299, Nb tracks: 1
# Album Id: 300, Nb tracks: 1
# Album Id: 301, Nb tracks: 1
# Album Id: 302, Nb tracks: 1
# Album Id: 303, Nb tracks: 1
# Album Id: 304, Nb tracks: 1
# Album Id: 305, Nb tracks: 1
# Album Id: 306, Nb tracks: 1
# Album Id: 307, Nb tracks: 1
# Album Id: 308, Nb tracks: 1
# Album Id: 309, Nb tracks: 1
# Album Id: 310, Nb tracks: 1
# Album Id: 311, Nb tracks: 1
# Album Id: 312, Nb tracks: 1
# Album Id: 313, Nb tracks: 1
# Album Id: 314, Nb tracks: 2
# Album Id: 315, Nb tracks: 1
# Album Id: 316, Nb tracks: 1
# Album Id: 317, Nb tracks: 1
# Album Id: 318, Nb tracks: 1
# Album Id: 319, Nb tracks: 1
# Album Id: 320, Nb tracks: 1
# Album Id: 321, Nb tracks: 12
# Album Id: 322, Nb tracks: 11
# Album Id: 323, Nb tracks: 1
# Album Id: 324, Nb tracks: 1
# Album Id: 325, Nb tracks: 1
# Album Id: 326, Nb tracks: 1
# Album Id: 327, Nb tracks: 1
# Album Id: 328, Nb tracks: 1
# Album Id: 329, Nb tracks: 1
# Album Id: 330, Nb tracks: 1
# Album Id: 331, Nb tracks: 1
# Album Id: 332, Nb tracks: 1
# Album Id: 333, Nb tracks: 1
# Album Id: 334, Nb tracks: 1
# Album Id: 335, Nb tracks: 1
# Album Id: 336, Nb tracks: 1
# Album Id: 337, Nb tracks: 1
# Album Id: 338, Nb tracks: 1
# Album Id: 339, Nb tracks: 1
# Album Id: 340, Nb tracks: 1
# Album Id: 341, Nb tracks: 1
# Album Id: 342, Nb tracks: 1
# Album Id: 343, Nb tracks: 1
# Album Id: 344, Nb tracks: 1
# Album Id: 345, Nb tracks: 1
# Album Id: 346, Nb tracks: 1
# Album Id: 347, Nb tracks: 1
#
# ############ Average track duration ###########
#
# Average track duration (in milliseconds): 393599.2121039109
#
# ############ Adding new artist ###########
#
#
# ############ Artists who have no registered album ###########
#
# 25 Milton Nascimento & Bebeto
# 26 Azymuth
# 28 João Gilberto
# 29 Bebel Gilberto
# 30 Jorge Vercilo
# 31 Baby Consuelo
# 32 Ney Matogrosso
# 33 Luiz Melodia
# 34 Nando Reis
# 35 Pedro Luís & A Parede
# 38 Banda Black Rio
# 39 Fernanda Porto
# 40 Os Cariocas
# 43 A Cor Do Som
# 44 Kid Abelha
# 45 Sandra De Sá
# 47 Hermeto Pascoal
# 48 Barão Vermelho
# 49 Edson, DJ Marky & DJ Patife Featuring Fernanda Porto
# 60 Santana Feat. Dave Matthews
# 61 Santana Feat. Everlast
# 62 Santana Feat. Rob Thomas
# 63 Santana Feat. Lauryn Hill & Cee-Lo
# 64 Santana Feat. The Project G&B
# 65 Santana Feat. Maná
# 66 Santana Feat. Eagle-Eye Cherry
# 67 Santana Feat. Eric Clapton
# 71 Vinícius De Moraes & Baden Powell
# 73 Vinícius E Qurteto Em Cy
# 74 Vinícius E Odette Lara
# 75 Vinicius, Toquinho & Quarteto Em Cy
# 107 Motörhead & Girlschool
# 119 Peter Tosh
# 123 R.E.M. Feat. KRS-One
# 129 Simply Red
# 154 Whitesnake
# 160 Christina Aguilera featuring BigElf
# 161 Aerosmith & Sierra Leone's Refugee Allstars
# 162 Los Lonely Boys
# 163 Corinne Bailey Rae
# 164 Dhani Harrison & Jakob Dylan
# 165 Jackson Browne
# 166 Avril Lavigne
# 167 Big & Rich
# 168 Youssou N'Dour
# 169 Black Eyed Peas
# 170 Jack Johnson
# 171 Ben Harper
# 172 Snow Patrol
# 173 Matisyahu
# 174 The Postal Service
# 175 Jaguares
# 176 The Flaming Lips
# 177 Jack's Mannequin & Mick Fleetwood
# 178 Regina Spektor
# 181 Xis
# 182 Nega Gizza
# 183 Gustavo & Andres Veiga & Salazar
# 184 Rodox
# 185 Charlie Brown Jr.
# 186 Pedro Luís E A Parede
# 187 Los Hermanos
# 188 Mundo Livre S/A
# 189 Otto
# 190 Instituto
# 191 Nação Zumbi
# 192 DJ Dolores & Orchestra Santa Massa
# 193 Seu Jorge
# 194 Sabotage E Instituto
# 195 Stereo Maracana
# 239 Academy of St. Martin in the Fields, Sir Neville Marriner & William Bennett
#
# ############ Artists whose name starts with N ###########
#
# 32 Ney Matogrosso
# 34 Nando Reis
# 110 Nirvana
# 182 Nega Gizza
# 191 Nação Zumbi
# 203 Nicolaus Esterhazy Sinfonia
# 274 Nash Ensemble
# C:\Users\liza2\AppData\Local\Temp\ipykernel_23104\3084418804.py:7: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %% [markdown]
# ## Exercise 2
# Extend your program so that it also covers questions 2.5, 2.6 and 2.8 from previous Exercise Sheet.

# %%
#2.5 SELECT a.title, count(t.name) FROM albums a, tracks t, artists ar WHERE a.albumid = t.albumid AND ar.artistid = a.artistid AND ar.name = 'Philip Glass Ensemble' GROUP BY a.title;
print('\n############ Albums and number of song by Philip Glass Ensemble ###########\n')
q2_5 = session.query(Albums.title, func.count(Tracks.name)).join(Tracks).join(Artists).filter(Artists.name == 'Philip Glass Ensemble')

for _albums in q2_5.all():
    print(_albums.title, _albums[1])
    
#2.6 SELECT a.name FROM artists a, albums al, tracks t WHERE a.artistid = al.artistid AND al.albumid = t.albumid AND t.milliseconds >= (SELECT MAX(milliseconds) FROM tracks);
print('\n############ Artists who play the longest song in the database ###########\n')
q2_6 = session.query(Artists.name).join(Albums).join(Tracks).filter(Tracks.milliseconds >= session.query(func.max(Tracks.milliseconds)))

for _ar in q2_6.all():
    print(_ar.name)


#2.8 SELECT g.name FROM genres g WHERE g.genreid NOT IN (SELECT t.genreid FROM tracks t);
print('\n############ Genres for which there is no song ###########\n')
q2_8 = session.query(Genres.name).filter(~Genres.genreid.in_([x[0] for x in session.query(Tracks.genreid).all()]))

for _names in q2_8.all():
    print(_names[0])
# Out:
# ############ Albums and number of song by Philip Glass Ensemble ###########
#
# Koyaanisqatsi (Soundtrack from the Motion Picture) 1
#
# ############ Artists who play the longest song in the database ###########
#
# Battlestar Galactica
#
# ############ Genres for which there is no song ###########
# C:\Users\liza2\AppData\Local\Temp\ipykernel_23104\217689364.py:10: SAWarning: implicitly coercing SELECT object to scalar subquery; please use the .scalar_subquery() method to produce a scalar subquery.
#   q2_6 = session.query(Artists.name).join(Albums).join(Tracks).filter(Tracks.milliseconds >= session.query(func.max(Tracks.milliseconds)))
